# %% [markdown]
# # TriviaQA Inference with Activation Logging + Logprobs
#
# Runs TriviaQA inference (full dataset) with activation logging and response logprob capture enabled.
# Output is saved to `shared/triviaqa_logprob/`.
